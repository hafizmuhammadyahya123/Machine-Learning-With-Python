# %% [markdown]
# <a href="https://colab.research.google.com/github/hafizmuhammadyahya123/Machine-Learning-With-Python/blob/main/Pandas_Series_part_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv("/content/sales_data_sample.csv",encoding='latin1')
df
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0           10107               30      95.70                2  2871.00
# 1           10121               34      81.35                5  2765.90
# 2           10134               41      94.74                2  3884.34
# 3           10145               45      83.26                6  3746.70
# 4           10159               49     100.00               14  5205.27
# ...           ...              ...        ...              ...      ...
# 2818        10350               20     100.00               15  2244.40
# 2819        10373               29     100.00                1  3978.51
# 2820        10386               43     100.00                4  5417.57
# 2821        10397               34      62.24                1  2116.16
# 2822        10414               47      65.52                9  3079.44
#
#             ORDERDATE    STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# ...

# %%
df = pd.read_json("/content/sample_Data.json")
df
# Out:
#     id                                               name  \
# 0    1                                    Apple iPhone 12
# 1    2                                 Samsung Galaxy S21
# 2    3                                 Sony PlayStation 5
# 3    4                  LG OLED55CXPUA 55-inch 4K OLED TV
# 4    5        Bose QuietComfort 35 II Wireless Headphones
# 5    6                          Fitbit Versa 3 Smartwatch
# 6    7                             KitchenAid Stand Mixer
# 7    8                 Dyson V11 Absolute Cordless Vacuum
# 8    9                         Ninja Foodi Smart XL Grill
# 9   10                    Canon EOS Rebel T8i DSLR Camera
# 10  11                                  Apple AirPods Pro
# 11  12        Bose QuietComfort 35 II Wireless Headphones
# 12  13                    Fitbit Charge 4 Fitness Tracker
# 13  14                              Samsung Galaxy Watch3
# 14  15  Sony WH-1000XM4 Wireless Noise-Cancelling Head...
# ...

# %% [markdown]
# # create data and build dataframe

# %%
# build csv file
data = {

        "NAME":["umer","usman","muavia"],
        "age":[22,25,26],
        "roll_number":[1001,1011,2001]
}

df = pd.DataFrame(data)
print(df)
# save this file using to_csv
df.to_csv("students.csv",index=False)
# Out:
#      NAME  age  roll_number
# 0    umer   22         1001
# 1   usman   25         1011
# 2  muavia   26         2001

# %% [markdown]
# # create data and build dataframe

# %%
# build xlsx file

data = {

        "NAME":["umer","usman","muavia"],
        "age":[22,25,26],
        "roll_number":[1001,1011,2001]
}

df = pd.DataFrame(data)
print(df)
# save this file using to_csv
df.to_excel("students.xlsx",index=False)
# Out:
#      NAME  age  roll_number
# 0    umer   22         1001
# 1   usman   25         1011
# 2  muavia   26         2001

# %% [markdown]
# # create data and build dataframe

# %%
# build json file
data = {

        "NAME":["umer","usman","muavia"],
        "age":[22,25,26],
        "roll_number":[1001,1011,2001]
}

df = pd.DataFrame(data)
print(df)
# save this file using to_csv
df.to_json("students.json",index=False)
# Out:
#      NAME  age  roll_number
# 0    umer   22         1001
# 1   usman   25         1011
# 2  muavia   26         2001

# %% [markdown]
# # **`DEAL ROWS`**
#
# # head()  tail()

# %%
import pandas as pd

df = pd.read_json("/content/sample_Data.json")
print(df.head(3))
print(df.tail(3))
# Out:
#    id                name                                        description  \
# 0   1     Apple iPhone 12  The Apple iPhone 12 features a 6.1-inch Super ...
# 1   2  Samsung Galaxy S21  The Samsung Galaxy S21 features a 6.2-inch Dyn...
# 2   3  Sony PlayStation 5  The Sony PlayStation 5 features an AMD Zen 2-b...
#
#     price     category                                              image
# 0  999.00  Electronics  https://www.apple.com/newsroom/images/product/...
# 1  799.00  Electronics  https://images.samsung.com/is/image/samsung/p6...
# 2  499.99  Electronics  https://www.sony.com/image/44baa604124b770c824...
#     id                              name  \
# 17  18    iRobot Roomba i7+ Robot Vacuum
# 18  19  Ninja Foodi Digital Air Fry Oven
# 19  20  Cuisinart ICE-70 Ice Cream Maker
#
#                                           description   price        category  \
# 17  The iRobot Roomba i7+ Robot Vacuum features au...  799.99  Home & Kitchen
# ...

# %%
# info() data set ki summary btata ha
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           20 non-null     int64
#  1   name         20 non-null     object
#  2   description  20 non-null     object
#  3   price        20 non-null     float64
#  4   category     20 non-null     object
#  5   image        20 non-null     object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 1.1+ KB
