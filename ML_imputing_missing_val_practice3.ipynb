# %% [markdown]
# <a href="https://colab.research.google.com/github/hafizmuhammadyahya123/Machine-Learning-With-Python/blob/main/ML_imputing_missing_val_practice3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # SIMPLE IMPUTATION TECHNIQUE

# %% [markdown]
# # MEAN IMPUTATION

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# load titanic dataset
df = sns.load_dataset('titanic')
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
# check the num of miss values in each column
df.isnull().sum().sort_values(ascending=False)
# Out:
# deck           688
# age            177
# embarked         2
# embark_town      2
# sex              0
# pclass           0
# survived         0
# fare             0
# parch            0
# sibsp            0
# class            0
# adult_male       0
# who              0
# alive            0
# alone            0
# dtype: int64

# %%
# drop deck column
df.drop('deck',axis=1,inplace=True)  #inplace means modify column
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male  embark_town alive  alone
# 0    man        True  Southampton    no  False
# 1  woman       False    Cherbourg   yes  False
# 2  woman       False  Southampton   yes   True
# 3  woman       False  Southampton   yes  False
# 4    man        True  Southampton    no   True

# %%
# dosra tarekah
# impute missing values with mean
df['age'] = df['age'].fillna(df['age'].mean)


# check the num of miss values in each column
df.isnull().sum().sort_values(ascending=False)
# Out:
# embark_town    2
# embarked       2
# sex            0
# age            0
# survived       0
# pclass         0
# parch          0
# sibsp          0
# class          0
# fare           0
# who            0
# adult_male     0
# alive          0
# alone          0
# dtype: int64

# %% [markdown]
# SIMPLE IMPUTATION TECHNIQUE

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
# load the titanic data set
df = sns.load_dataset('titanic')
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
# check the num of missing values in each columnn
df.isnull().sum().sort_values(ascending=False)
# Out:
# deck           688
# age            177
# embarked         2
# embark_town      2
# sex              0
# pclass           0
# survived         0
# fare             0
# parch            0
# sibsp            0
# class            0
# adult_male       0
# who              0
# alive            0
# alone            0
# dtype: int64

# %%
# drop deck column
df.drop('deck',axis=1,inplace=True)
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male  embark_town alive  alone
# ...

# %%
# impute missing values with mean
df['age'] = df['age'].fillna(df['age'].mean)

# check the missing values in each column
df.isnull().sum().sort_values(ascending=False)
# Out:
# embark_town    2
# embarked       2
# sex            0
# age            0
# survived       0
# pclass         0
# parch          0
# sibsp          0
# class          0
# fare           0
# who            0
# adult_male     0
# alive          0
# alone          0
# dtype: int64

# %%
# impute missing values with median
df['embarked'] = df['embarked'].fillna(df['embarked'].median)

# check the missing values in each column
df.isnull().sum().sort_values(ascending=False)
# Out:
# embark_town    2
# survived       0
# sex            0
# age            0
# sibsp          0
# pclass         0
# parch          0
# fare           0
# class          0
# embarked       0
# who            0
# adult_male     0
# alive          0
# alone          0
# dtype: int64

# %%
# impoute the missing values with mode
df['embark_town'] = df['embark_town'].fillna(df['embark_town'].mode()[0])

# check the missing values in each column
df.isnull().sum().sort_values(ascending=False)
# Out:
# survived       0
# pclass         0
# sex            0
# age            0
# sibsp          0
# parch          0
# fare           0
# embarked       0
# class          0
# who            0
# adult_male     0
# embark_town    0
# alive          0
# alone          0
# dtype: int64

# %% [markdown]
# simple imputayion technique

# %%
# import libraries
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
# load data set
df = sns.load_dataset('titanic')
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
# check the missing values in each column
df.isnull().sum().sort_values(ascending=False)
# Out:
# deck           688
# age            177
# embarked         2
# embark_town      2
# sex              0
# pclass           0
# survived         0
# fare             0
# parch            0
# sibsp            0
# class            0
# adult_male       0
# who              0
# alive            0
# alone            0
# dtype: int64

# %%
# drop deck column
df.drop('deck',axis=1,inplace=True)
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male  embark_town alive  alone
# 0    man        True  Southampton    no  False
# 1  woman       False    Cherbourg   yes  False
# 2  woman       False  Southampton   yes   True
# 3  woman       False  Southampton   yes  False
# 4    man        True  Southampton    no   True

# %%
# impute missing values with mean
df['age'] = df['age'].fillna(df['age'].mean)

# check the missing values in each column
df.isnull().sum().sort_values(ascending=False)
# Out:
# embark_town    2
# embarked       2
# sex            0
# age            0
# survived       0
# pclass         0
# parch          0
# sibsp          0
# class          0
# fare           0
# who            0
# adult_male     0
# alive          0
# alone          0
# dtype: int64

# %%
# impute the missing values with median
df['embarked'] = df['embarked'].fillna(df['embarked'].median)

# check the missing values in each columns
df.isnull().sum().sort_values(ascending=False)
# Out:
# embark_town    2
# survived       0
# sex            0
# age            0
# sibsp          0
# pclass         0
# parch          0
# fare           0
# class          0
# embarked       0
# who            0
# adult_male     0
# alive          0
# alone          0
# dtype: int64

# %%
# impute the missing values with mode
df['embark_town'] = df['embark_town'].fillna(df['embark_town'].mode()[0])

# check the number of missing values in each column
df.isnull().sum().sort_values(ascending=False)
# Out:
# survived       0
# pclass         0
# sex            0
# age            0
# sibsp          0
# parch          0
# fare           0
# embarked       0
# class          0
# who            0
# adult_male     0
# embark_town    0
# alive          0
# alone          0
# dtype: int64

# %%
df
# Out:
#      survived  pclass     sex  \
# 0           0       3    male
# 1           1       1  female
# 2           1       3  female
# 3           1       1  female
# 4           0       3    male
# ..        ...     ...     ...
# 886         0       2    male
# 887         1       1  female
# 888         0       3  female
# 889         1       1    male
# 890         0       3    male
#
#                                                    age  sibsp  parch     fare  \
# 0                                                 22.0      1      0   7.2500
# 1                                                 38.0      1      0  71.2833
# 2                                                 26.0      0      0   7.9250
# 3                                                 35.0      1      0  53.1000
# 4                                                 35.0      0      0   8.0500
# ..                                                 ...    ...    ...      ...
# ...
